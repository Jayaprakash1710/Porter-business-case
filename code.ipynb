# %%
#analysing and handling data
import numpy as np
import pandas as pd

#visualizing
import matplotlib.pyplot as plt
import seaborn as sns

#preprocessing
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv(r'C:\Users\USER\Documents\GitHub\Porter-business-case\porter_dataset.csv')
df.head()
# Out:
#    market_id           created_at actual_delivery_time  \
# 0        1.0  2015-02-06 22:24:17  2015-02-06 23:27:16
# 1        2.0  2015-02-10 21:49:25  2015-02-10 22:56:29
# 2        3.0  2015-01-22 20:39:28  2015-01-22 21:09:09
# 3        3.0  2015-02-03 21:21:45  2015-02-03 22:13:00
# 4        3.0  2015-02-15 02:40:36  2015-02-15 03:20:26
#
#                            store_id store_primary_category  order_protocol  \
# 0  df263d996281d984952c07998dc54358               american             1.0
# 1  f0ade77b43923b38237db569b016ba25                mexican             2.0
# 2  f0ade77b43923b38237db569b016ba25                    NaN             1.0
# 3  f0ade77b43923b38237db569b016ba25                    NaN             1.0
# 4  f0ade77b43923b38237db569b016ba25                    NaN             1.0
#
#    total_items  subtotal  num_distinct_items  min_item_price  max_item_price  \
# 0            4      3441                   4             557            1239
# ...

# %%
df.groupby('store_id')['market_id'].mode()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df.groupby('store_id')['market_id'].mode()
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:1363, in GroupBy.__getattr__(self, attr)
#    1360 if attr in self.obj:
#    1361     return self[attr]
# -> 1363 raise AttributeError(
#    1364     f"'{type(self).__name__}' object has no attribute '{attr}'"
#    1365 )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'mode'

# %%
df.groupby('market_id')['store_id'].count()
# Out:
# market_id
# 1.0    38037
# 2.0    55058
# 3.0    23297
# 4.0    47599
# 5.0    18000
# 6.0    14450
# Name: store_id, dtype: int64

# %%
df[df['store_id']=='0004d0b59e19461ff126e3a08a814c33']
# Out:
#         market_id           created_at actual_delivery_time  \
# 138197        4.0  2015-02-17 19:41:16  2015-02-17 20:13:36
# 138198        4.0  2015-02-01 17:32:05  2015-02-01 18:13:38
# 138199        4.0  2015-02-05 01:25:01  2015-02-05 02:12:02
# 138200        4.0  2015-01-29 17:58:19  2015-01-29 18:27:18
# 138201        4.0  2015-01-24 18:33:18  2015-01-24 19:04:04
# ...           ...                  ...                  ...
# 138310        4.0  2015-01-22 20:35:39  2015-01-22 21:02:35
# 138311        4.0  2015-02-13 19:06:34  2015-02-13 19:41:44
# 138312        4.0  2015-02-08 19:55:54  2015-02-08 20:42:12
# 138313        4.0  2015-02-05 18:17:15  2015-02-05 19:03:02
# 138314        4.0  2015-02-15 17:03:24  2015-02-15 17:45:08
#
#                                 store_id store_primary_category  \
# 138197  0004d0b59e19461ff126e3a08a814c33               american
# 138198  0004d0b59e19461ff126e3a08a814c33               american
# ...
